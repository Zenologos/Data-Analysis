# %% [markdown]
# <a href="https://colab.research.google.com/github/Zenologos/Data-Analysis/blob/master/Python_Lesson_3_DataFrames_part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DataFrames Part 2

# %% [markdown]
# In this part we'll continue our exploration of the pandas dataframe object and the focus here will be filtration or filtering our data sets.
#
# Basically that means taking a subset of our main dataframe based on a certain condition being met or not met or perhaps multiple conditions being met.
#
# We'll explore all the different ways that we can essentially take a larger dataframe and extract those rows that match a specific condition kind of looking at a subset of our main data frame.

# %%
import pandas as pd

# %%
df = pd.read_csv("Data/employees.csv")
df.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
df["Start Date"] = pd.to_datetime(df["Start Date"])

# %%
df["Last Login Time"] = pd.to_datetime(df["Last Login Time])

# %%
df["Senior Management"] = df["Senior Management"].astype("bool")

# %%
df["Gender"] = df["Gender"].astype("category")

# %% [markdown]
# We can do all these together and also use the Parse_date() method

# %%
df = pd.read_csv("employees.csv", parse_dates = ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-04-02 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-04-02 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-04-02 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %% [markdown]
# ## Filter A `DataFrame` Based On A Condition

# %%
df["Gender"]
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 995       NaN
# 996      Male
# 997      Male
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: category
# Categories (2, object): [Female, Male]

# %%
#we can create a boolean series with the condition double equal
df["Gender"] == "Female"
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Gender, Length: 1000, dtype: bool

# %% [markdown]
# Here we use 2 square brackets.
#
# The first bracket operating on that internal code first and that's generating the boolean series.
#
# We want it to only extract those rows that have a true value from dataframe.   And in this case those rows with a true value will be those that have Female.
# So now if we execute this code with 2 square brackets we're going to get a new data frame where you can see that it is only taken the rows that have male so there's no male present.

# %%
df[df["Gender"] == "Female"]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2020-04-02 11:17:00  130590   11.858
# 6         Ruby  Female 1987-08-17 2020-04-02 16:20:00   65476   10.012
# 7          NaN  Female 2015-07-20 2020-04-02 10:43:00   45906   11.598
# 8       Angela  Female 2005-11-22 2020-04-02 06:29:00   95570   18.523
# 9      Frances  Female 2002-08-08 2020-04-02 06:51:00  139852    7.524
# ..         ...     ...        ...                 ...     ...      ...
# 987     Gloria  Female 2014-12-08 2020-04-02 05:08:00  136709   10.331
# 988      Alice  Female 2004-10-05 2020-04-02 09:34:00   47638   11.209
# 990      Robin  Female 1987-07-24 2020-04-02 13:35:00  100765   10.982
# 991       Rose  Female 2002-08-25 2020-04-02 05:12:00  134505   11.051
# 993       Tina  Female 1997-05-15 2020-04-02 15:53:00   56450   19.040
#
#      Senior Management                  Team
# 2                False               Finance
# 6                 True               Product
# 7                 True               Finance
# 8                 True           Engineering
# 9                 True  Business Development
# ..                 ...                   ...
# 987               True               Finance
# 988              False       Human Resources
# 990               True       Client Services
# 991               True             Marketing
# 993               True           Engineering
#
# [431 rows x 8 columns]

# %% [markdown]
# Let's say we want to pull every person who's on the team of Finance.

# %%
df["Team"]== "Finace"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Team, Length: 1000, dtype: bool

# %%
df[df["Team"]== "Finance"]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2020-04-02 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-04-02 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2020-04-02 10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14 2020-04-02 07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28 2020-04-02 22:47:00  114796    6.796
# ..         ...     ...        ...                 ...     ...      ...
# 907  Elizabeth  Female 1998-07-27 2020-04-02 11:12:00  137144   10.081
# 954        Joe    Male 1980-01-19 2020-04-02 16:06:00  119667    1.148
# 987     Gloria  Female 2014-12-08 2020-04-02 05:08:00  136709   10.331
# 992    Anthony    Male 2011-10-16 2020-04-02 08:35:00  112769   11.625
# 996    Phillip    Male 1984-01-31 2020-04-02 06:30:00   42392   19.675
#
#      Senior Management     Team
# 2                False  Finance
# 3                 True  Finance
# 7                 True  Finance
# 14                True  Finance
# 46               False  Finance
# ..                 ...      ...
# 907              False  Finance
# 954               True  Finance
# 987               True  Finance
# 992               True  Finance
# 996              False  Finance
#
# [102 rows x 8 columns]

# %% [markdown]
# ## there is a more elegant way to do this

# %%
df["Team"]== "Finance"
#Output = None
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 995    False
# 996     True
# 997    False
# 998    False
# 999    False
# Name: Team, Length: 1000, dtype: bool

# %%
mask = df["Team"]== "Finance"

# %%
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2020-04-02 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-04-02 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2020-04-02 10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14 2020-04-02 07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28 2020-04-02 22:47:00  114796    6.796
# ..         ...     ...        ...                 ...     ...      ...
# 907  Elizabeth  Female 1998-07-27 2020-04-02 11:12:00  137144   10.081
# 954        Joe    Male 1980-01-19 2020-04-02 16:06:00  119667    1.148
# 987     Gloria  Female 2014-12-08 2020-04-02 05:08:00  136709   10.331
# 992    Anthony    Male 2011-10-16 2020-04-02 08:35:00  112769   11.625
# 996    Phillip    Male 1984-01-31 2020-04-02 06:30:00   42392   19.675
#
#      Senior Management     Team
# 2                False  Finance
# 3                 True  Finance
# 7                 True  Finance
# 14                True  Finance
# 46               False  Finance
# ..                 ...      ...
# 907              False  Finance
# 954               True  Finance
# 987               True  Finance
# 992               True  Finance
# 996              False  Finance
#
# [102 rows x 8 columns]

# %% [markdown]
# Filtering based on a condition not being met.
# So let's say we want to pull any person who is not on the team of marketing.

# %%
df["Team"] != "Marketing"
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Team, Length: 1000, dtype: bool

# %%
mask = df["Team"] != "Marketing"
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2020-04-02 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-04-02 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-04-02 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-04-02 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2020-04-02 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-04-02 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-04-02 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-04-02 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-04-02 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-04-02 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [902 rows x 8 columns]

# %%
df["Salary"] > 100000
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999     True
# Name: Salary, Length: 1000, dtype: bool

# %%
mask = df["Salary"] > 100000

# %%
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2020-04-02 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-04-02 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-04-02 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2020-04-02 01:35:00  115163   10.125
# 9      Frances  Female 2002-08-08 2020-04-02 06:51:00  139852    7.524
# ..         ...     ...        ...                 ...     ...      ...
# 990      Robin  Female 1987-07-24 2020-04-02 13:35:00  100765   10.982
# 991       Rose  Female 2002-08-25 2020-04-02 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2020-04-02 08:35:00  112769   11.625
# 995      Henry     NaN 2014-11-23 2020-04-02 06:09:00  132483   16.655
# 999     Albert    Male 2012-05-15 2020-04-02 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# 9                 True  Business Development
# ..                 ...                   ...
# 990               True       Client Services
# 991               True             Marketing
# 992               True               Finance
# 995              False          Distribution
# 999               True                 Sales
#
# [409 rows x 8 columns]

# %% [markdown]
# ## Filter with More than One Condition (AND)

# %% [markdown]
# For filtering our data frames using more than one condition, there's actually two ways that we can do this.
#
# - The first is using an AND operator which means that both conditions have to be true condition A and condition B.
# - then using the OR operator which means either condition is true, condition B is true or both.

# %%
df = pd.read_csv("employees.csv", parse_dates = ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-04
# 960    Stephen    Male 1989-10-29 2016-09-04 23:34:00   93997   18.093
# 961    Antonio     NaN 1989-06-18 2016-09-04 21:37:00  103050    3.050
# 963        Ann  Female 1994-09-23 2016-09-04 11:15:00   89443   17.940
# 964      Bruce    Male 1980-05-07 2016-09-04 20:00:00   35802   12.391
# 965  Catherine  Female 1989-09-25 2016-09-04 01:31:00   68164   18.393
# 966      Louis    Male 2011-08-16 2016-09-04 17:19:00   93022    9.146
# 969      Linda  Female 2010-02-04 2016-09-04 20:49:00   44486   17.308
# 970      Alice  Female 1988-09-03 2016-09-04 20:54:00   63571   15.397
# 971    Patrick    Male 2002-12-30 2016-09-04 02:01:00   75423    5.368
# 972     Victor     NaN 2006-07-28 2016-09-04 14:49:00   76381   11.159
# 974      Harry    Male 2011-08-30 2016-09-04 18:31:00   67656   16.455
# 976     Denise  Female 1992-10-19 2016-09-04 05:42:00  137954    4.195
# 978       Sean    Male 1983-01-17 2016-09-04 14:23:00   66146   11.178
# 979     Ernest    Male 2013-07-20 2016-09-04 06:41:00  142935   13.198
# 980   Kimberly  Female 2013-01-26 2016-09-04 00:57:00   46233    8.862
# 982       Rose  Female 1982-04-06 2016-09-04 10:43:00   91411    8.639
# 983       John    Male 1982-12-23 2016-09-04 22:35:00  146907   11.738
# 985    Stephen     NaN 1983-07-10 2016-09-04 20:10:00   85668    1.909
# 986      Donna  Female 1982-11-26 2016-09-04 07:04:00   82871   17.999
# 987     Gloria  Female 2014-12-08 2016-09-04 05:08:00  136709   10.331
# 990      Robin  Female 1987-07-24 2016-09-04 13:35:00  100765   10.982
# 991       Rose  Female 2002-08-25 2016-09-04 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2016-09-04 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2016-09-04 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2016-09-04 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2016-09-04 06:30:00   42392   19.675
# 999     Albert    Male 2012-05-15 2016-09-04 18:24:00  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 3                True               Finance
# 4                True       Client Services
# 5               False                 Legal
# 6                True               Product
# 7                True               Finance
# 8                True           Engineering
# 9                True  Business Development
# 10               True                   NaN
# 11               True                 Legal
# 12               True       Human Resources
# 14               True               Finance
# 17              False               Product
# 18              False       Client Services
# 20               True                 Legal
# 22               True       Client Services
# 23               True                   NaN
# 25               True       Client Services
# 26               True             Marketing
# 28               True       Client Services
# 29               True                 Legal
# 30               True           Engineering
# 32               True                   NaN
# 37               True       Client Services
# 38               True  Business Development
# 39               True       Client Services
# 40               True          Distribution
# 41               True  Business Development
# 43               True             Marketing
# ..                ...                   ...
# 957              True                 Sales
# 958             False           Engineering
# 959              True  Business Development
# 960              True  Business Development
# 961             False                 Legal
# 963              True                 Sales
# 964              True                 Sales
# 965             False       Client Services
# 966              True       Human Resources
# 969              True           Engineering
# 970              True               Product
# 971              True  Business Development
# 972              True                 Sales
# 974              True       Client Services
# 976              True                 Legal
# 978             False       Human Resources
# 979              True               Product
# 980              True           Engineering
# 982              True       Human Resources
# 983             False           Engineering
# 985             False                 Legal
# 986             False             Marketing
# 987              True               Finance
# 990              True       Client Services
# 991              True             Marketing
# 992              True               Finance
# 993              True           Engineering
# 994              True             Marketing
# 996             False               Finance
# 999              True                 Sales
#
# [653 rows x 8 columns]

# %% [markdown]
# We can create three separate Boullion series.
#
# Let's extract our team series with our square brackets. We'll get our bullion series.

# %%
mask1 = df["First Name"] == "Robert"
mask2 = df["Team"] == "Client Services"
mask3 = df["Start Date"] > "2016-06-01"

df[(mask1 & mask2) | mask3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2020-04-02 06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16 2020-04-02 19:47:00  100705   16.961
# 387     Robert    Male 1994-10-29 2020-04-02 04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15 2020-04-02 00:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing

# %% [markdown]
# ## The `.isin()` Method

# %%
df = pd.read_csv("employees.csv", parse_dates = ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-04-02 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-04-02 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-04-02 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %% [markdown]
# We can run this filltering.

# %%
mask1 = df["Team"] == "Legal"
mask2 = df["Team"] == "Sales"
mask3 = df["Team"] == "Product"

df[mask1 | mask2 | mask3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2020-04-02 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2020-04-02 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2020-04-02 15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 2020-04-02 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2020-04-02 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 981      James    Male 1993-01-15 2020-04-02 17:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10 2020-04-02 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2020-04-02 16:58:00   38344    3.794
# 997    Russell    Male 2013-05-20 2020-04-02 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2020-04-02 18:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# 11                True    Legal
# 13               False    Sales
# 15               False  Product
# ..                 ...      ...
# 981              False    Legal
# 985              False    Legal
# 989              False    Legal
# 997              False  Product
# 999               True    Sales
#
# [277 rows x 8 columns]

# %% [markdown]
# But if you have something like a python list of 100 teams and you want to check whether the values in a series are in that list you really don't want to be writing a hundred different boolean series. it's an incredible waste of time.
#
# So the method takes care of this problem. We can use isin() method which we can pass a Python list inside the bracket.

# %%
df["Team"].isin(["Legal", "Sales", "Product"])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997     True
# 998    False
# 999     True
# Name: Team, Length: 1000, dtype: bool

# %%
mask = df["Team"].isin(["Legal", "Sales", "Product"])

# %%
#here we get exactly the same df as before
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2020-04-02 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-04-02 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-04-02 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2020-04-02 01:35:00  115163   10.125
# 9      Frances  Female 2002-08-08 2020-04-02 06:51:00  139852    7.524
# ..         ...     ...        ...                 ...     ...      ...
# 990      Robin  Female 1987-07-24 2020-04-02 13:35:00  100765   10.982
# 991       Rose  Female 2002-08-25 2020-04-02 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2020-04-02 08:35:00  112769   11.625
# 995      Henry     NaN 2014-11-23 2020-04-02 06:09:00  132483   16.655
# 999     Albert    Male 2012-05-15 2020-04-02 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# 9                 True  Business Development
# ..                 ...                   ...
# 990               True       Client Services
# 991               True             Marketing
# 992               True               Finance
# 995              False          Distribution
# 999               True                 Sales
#
# [409 rows x 8 columns]

# %% [markdown]
# ## The `.isnull()` and `.notnull()` Methods

# %%
df = pd.read_csv("employees.csv", parse_dates = ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2016-09-23 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2016-09-23 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2016-09-23 11:17:00  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %% [markdown]
# Let's say we want to extract the rows from the data frame where the value in our team column is null.

# %%
df["Team"].isnull()
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Team, Length: 1000, dtype: bool

# %%
mask = df["Team"].isnull()

df[mask]
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31 2016-09-23 06:53:00   61933    4.170
# 10        Louise  Female 1980-08-12 2016-09-23 09:01:00   63241   15.132
# 23           NaN    Male 2012-06-14 2016-09-23 16:19:00  125792    5.042
# 32           NaN    Male 1998-08-21 2016-09-23 14:27:00  122340    6.417
# 91         James     NaN 2005-01-26 2016-09-23 23:00:00  128771    8.309
# 109  Christopher    Male 2000-04-22 2016-09-23 10:15:00   37919   11.449
# 139          NaN  Female 1990-10-03 2016-09-23 01:08:00  132373   10.527
# 199     Jonathan    Male 2009-07-17 2016-09-23 08:15:00  130581   16.736
# 258      Michael    Male 2002-01-24 2016-09-23 03:04:00   43586   12.659
# 290       Jeremy    Male 1988-06-14 2016-09-23 18:20:00  129460   13.657
# 314        Bobby    Male 1996-03-31 2016-09-23 17:40:00  112117    6.338
# 367       Edward    Male 1989-08-04 2016-09-23 06:06:00   66067   10.957
# 382          NaN  Female 1996-04-18 2016-09-23 15:57:00  107024   12.182
# 434        Joyce  Female 1995-02-07 2016-09-23 07:38:00   50701   14.227
# 438        Jason    Male 1998-11-20 2016-09-23 14:54:00   69244    6.220
# 445        Chris    Male 2006-12-12 2016-09-23 01:57:00   71642    1.496
# 479      Richard    Male 1997-07-04 2016-09-23 11:47:00   47647   18.787
# 512        Wanda  Female 1993-04-06 2016-09-23 03:11:00   78883   19.695
# 513        Jimmy    Male 2013-11-19 2016-09-23 19:29:00   63549   19.624
# 520        Peter    Male 2003-02-22 2016-09-23 09:09:00   56580    8.411
# 567          NaN  Female 1980-04-01 2016-09-23 20:04:00   48141   12.605
# 573     Kimberly  Female 1981-12-30 2016-09-23 04:51:00   81800    5.435
# 580        Harry    Male 1985-01-27 2016-09-23 20:18:00   65482   18.089
# 626          NaN  Female 1997-04-13 2016-09-23 08:03:00  131755    2.930
# 634         Carl    Male 1987-03-30 2016-09-23 17:59:00   75598   19.289
# 635        Randy    Male 2000-09-27 2016-09-23 03:04:00   89831   13.047
# 647       Donald    Male 1988-04-06 2016-09-23 10:00:00  122920    5.320
# 669       Joseph     NaN 1982-03-28 2016-09-23 13:05:00   86564   11.879
# 684        Alice  Female 2016-01-21 2016-09-23 17:07:00  117787   10.485
# 706         Todd    Male 1993-07-04 2016-09-23 18:53:00  128175   18.473
# 726       Daniel    Male 2016-02-29 2016-09-23 04:04:00   77287   13.000
# 753      Antonio    Male 1999-06-06 2016-09-23 22:54:00   41928    5.478
# 774          NaN  Female 2000-06-18 2016-09-23 07:36:00  106428   10.867
# 781     Lawrence    Male 1995-07-03 2016-09-23 22:55:00   46378    9.127
# 794       Nicole  Female 2004-03-01 2016-09-23 17:17:00   44021   10.286
# 826          NaN     NaN 1988-08-01 2016-09-23 01:35:00   87103    5.665
# 850      Charles    Male 1997-09-03 2016-09-23 10:04:00  148291    6.002
# 851        Bobby    Male 1996-08-19 2016-09-23 01:16:00  147842   16.158
# 853      Mildred  Female 2007-04-06 2016-09-23 22:06:00  139284   11.390
# 855      Phillip     NaN 2003-10-20 2016-09-23 11:09:00   89700    2.277
# 864         Ryan    Male 2012-11-16 2016-09-23 13:47:00   57292    6.010
# 912          Joe    Male 1998-12-08 2016-09-23 10:28:00  126120    1.020
# 951          NaN  Female 2010-09-14 2016-09-23 05:19:00  143638    9.662
#
#     Senior Management Team
# 1                True  NaN
# 10               True  NaN
# 23               True  NaN
# 32               True  NaN
# 91              False  NaN
# 109             False  NaN
# 139              True  NaN
# 199              True  NaN
# 258             False  NaN
# 290              True  NaN
# 314             False  NaN
# 367              True  NaN
# 382              True  NaN
# 434              True  NaN
# 438              True  NaN
# 445             False  NaN
# 479              True  NaN
# 512             False  NaN
# 513             False  NaN
# 520              True  NaN
# 567              True  NaN
# 573              True  NaN
# 580             False  NaN
# 626              True  NaN
# 634             False  NaN
# 635              True  NaN
# 647             False  NaN
# 669              True  NaN
# 684             False  NaN
# 706              True  NaN
# 726              True  NaN
# 753              True  NaN
# 774              True  NaN
# 781             False  NaN
# 794             False  NaN
# 826              True  NaN
# 850             False  NaN
# 851              True  NaN
# 853              True  NaN
# 855              True  NaN
# 864             False  NaN
# 912             False  NaN
# 951              True  NaN

# %%
df["Gender"].notnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
condition = df["Gender"].notnull()

df[condition]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-04-02 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-04-02 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-04-02 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-04-02 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-04-02 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2020-04-02 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2020-04-02 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-04-02 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-04-02 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-04-02 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 994               True             Marketing
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [855 rows x 8 columns]

# %% [markdown]
# ## The `.between()` Method

# %% [markdown]
# The between method is like many of the method so far is called directly on a series and helps to generate a brand new Boullion series.
#
# And as you might guess the between method is helpful when we want to find values that fall between a range or within a specific range whether it is times or dates.

# %%
df = pd.read_csv("employees.csv", parse_dates = ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2016-09-23 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2016-09-23 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2016-09-23 11:17:00  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %% [markdown]
# Let's say I want to pull out all of the employees who had a salary between 60000 and 70000 inclusive.
#
# We could write one boolean series where we do greater than or equal to sixty thousand and another boolean series that we have less than or equal to 70000.
#
# Then use df[(mask1 & mask2)] to pull both of those conditions.
#
# But the between method makes it a lot simpler.
# It gets 2 argument, lower bound and upper bound.

# %%
df[df["Salary"].between(60000, 70000)]
# Out:
#      First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 
# 677  Jacqueline  Female 1994-09-20 2016-09-23 18:07:00   62371   15.770
# 679        Lori  Female 2002-09-11 2016-09-23 07:36:00   66029    3.345
# 704      Thomas    Male 1991-09-07 2016-09-23 09:51:00   65251   11.211
# 709         NaN    Male 1995-04-07 2016-09-23 04:32:00   60411   12.048
# 719        John    Male 1999-01-29 2016-09-23 03:07:00   67165   13.001
# 730      Nicole  Female 2009-04-26 2016-09-23 00:40:00   66047   18.674
# 742      Martin    Male 2016-02-25 2016-09-23 18:29:00   61117    2.844
# 745       James    Male 2008-02-16 2016-09-23 02:49:00   69111   14.625
# 747      Ernest    Male 2001-06-30 2016-09-23 13:46:00   61181   16.559
# 825      Robert     NaN 2000-12-04 2016-09-23 01:20:00   69267    5.890
# 831     Kenneth    Male 2015-01-15 2016-09-23 14:41:00   69112    7.588
# 854       Harry    Male 1985-02-10 2016-09-23 19:46:00   63046   10.411
# 892     Brandon    Male 1995-10-23 2016-09-23 12:04:00   60263    2.709
# 909      Donald    Male 1991-08-01 2016-09-23 02:25:00   61999    6.466
# 924     Deborah  Female 2003-11-11 2016-09-23 16:53:00   60003    9.624
# 937       Aaron     NaN 1986-01-22 2016-09-23 19:39:00   63126   18.424
# 943       Wayne    Male 2006-09-08 2016-09-23 11:09:00   67471    2.728
# 965   Catherine  Female 1989-09-25 2016-09-23 01:31:00   68164   18.393
# 970       Alice  Female 1988-09-03 2016-09-23 20:54:00   63571   15.397
# 974       Harry    Male 2011-08-30 2016-09-23 18:31:00   67656   16.455
# 978        Sean    Male 1983-01-17 2016-09-23 14:23:00   66146   11.178
# 998       Larry    Male 2013-04-20 2016-09-23 16:45:00   60500   11.985
#
#     Senior Management                  Team
# 1                True                   NaN
# 6                True               Product
# 10               True                   NaN
# 20               True                 Legal
# 41               True  Business Development
# 47               True       Client Services
# 57               True       Human Resources
# 59              False           Engineering
# 65               True          Distribution
# 74              False             Marketing
# 88               True                 Legal
# 101              True             Marketing
# 107             False                 Legal
# 112             False             Marketing
# 127             False       Human Resources
# 129              True  Business Development
# 159             False             Marketing
# 179              True               Finance
# 196             False       Client Services
# 197             False       Client Services
# 225              True                 Sales
# 231             False               Product
# 239             False       Human Resources
# 262              True           Engineering
# 285             False       Human Resources
# 286              True               Finance
# 288             False          Distribution
# 310              True                 Legal
# 320              True                 Sales
# 325             False       Client Services
# ..                ...                   ...
# 580             False                   NaN
# 597             False          Distribution
# 612              True          Distribution
# 613             False               Finance
# 614             False          Distribution
# 618             False               Finance
# 654             False                 Legal
# 668              True                 Legal
# 677              True       Client Services
# 679              True       Client Services
# 704             False          Distribution
# 709              True       Human Resources
# 719             False           Engineering
# 730              True             Marketing
# 742             False       Client Services
# 745              True  Business Development
# 747             False  Business Development
# 825              True                 Sales
# 831              True               Finance
# 854             False               Finance
# 892             False                 Sales
# 909             False               Product
# 924             False       Client Services
# 937             False       Client Services
# 943             False           Engineering
# 965             False       Client Services
# 970              True               Product
# 974              True       Client Services
# 978             False       Human Resources
# 998             False  Business Development
#
# [86 rows x 8 columns]

# %%
df[df["Bonus %"].between(2.0, 5.0)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2016-09-23 06:53:00   61933    4.170
# 20        Lois     NaN 1995-04-22 2016-09-23 19:18:00   64714    4.934
# 40     Michael    Male 2008-10-10 2016-09-23 11:25:00   99283    2.665
# 49       Chris     NaN 1980-01-24 2016-09-23 12:13:00  113590    3.055
# 60       Paula     NaN 2005-11-23 
# 922     Arthur    Male 2013-12-05 2016-09-23 08:44:00   86615    3.412
# 923      Irene     NaN 1991-02-28 2016-09-23 22:23:00  135369    4.380
# 928    Jeffrey    Male 1986-09-20 2016-09-23 06:06:00  111376    2.673
# 930      Nancy  Female 2001-09-10 2016-09-23 23:57:00   85213    2.386
# 931     Harold    Male 2012-06-23 2016-09-23 12:40:00  140444    3.771
# 932     Bonnie  Female 2008-12-23 2016-09-23 09:26:00   90427    2.010
# 933      Doris  Female 1993-07-05 2016-09-23 17:54:00  141439    3.799
# 934     Samuel    Male 1997-08-07 2016-09-23 12:40:00   43694    3.787
# 938       Mark     NaN 2006-09-09 2016-09-23 12:27:00   44836    2.657
# 939      Ralph     NaN 1995-07-28 2016-09-23 18:53:00   70635    2.147
# 943      Wayne    Male 2006-09-08 2016-09-23 11:09:00   67471    2.728
# 961    Antonio     NaN 1989-06-18 2016-09-23 21:37:00  103050    3.050
# 976     Denise  Female 1992-10-19 2016-09-23 05:42:00  137954    4.195
# 989     Justin     NaN 1991-02-10 2016-09-23 16:58:00   38344    3.794
# 994     George    Male 2013-06-21 2016-09-23 17:47:00   98874    4.479
#
#     Senior Management                  Team
# 1                True                   NaN
# 20               True                 Legal
# 40               True          Distribution
# 49              False                 Sales
# 60              False          Distribution
# 61              False  Business Development
# 66               True  Business Development
# 69               True               Finance
# 72              False               Product
# 73               True                 Sales
# 79              False               Product
# 85               True       Client Services
# 106             False                 Legal
# 112             False             Marketing
# 113              True           Engineering
# 115             False               Product
# 124              True               Product
# 133              True       Client Services
# 134              True  Business Development
# 146             False               Product
# 147             False                 Legal
# 173              True           Engineering
# 183              True          Distribution
# 193              True                 Legal
# 197             False       Client Services
# 203              True  Business Development
# 204              True             Marketing
# 208             False       Human Resources
# 214             False           Engineering
# 215             False       Client Services
# ..                ...                   ...
# 824             False             Marketing
# 829              True       Human Resources
# 834              True  Business Development
# 835             False           Engineering
# 840              True          Distribution
# 847             False               Finance
# 848              True               Product
# 855              True                   NaN
# 871              True           Engineering
# 873              True                 Sales
# 874              True       Human Resources
# 892             False                 Sales
# 896              True                 Sales
# 905              True               Finance
# 908             False           Engineering
# 922              True  Business Development
# 923             False  Business Development
# 928              True  Business Development
# 930              True             Marketing
# 931             False          Distribution
# 932              True       Client Services
# 933             False  Business Development
# 934              True           Engineering
# 938             False       Client Services
# 939             False       Client Services
# 943             False           Engineering
# 961             False                 Legal
# 976              True                 Legal
# 989             False                 Legal
# 994              True             Marketing
#
# [169 rows x 8 columns]

# %%
df[df["Start Date"].between("1991-01-01", "1992-01-01")]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 27       Scott     NaN 1991-07-11 2016-09-23 18:58:00  122367    5.218
# 75      Bonnie  Female 1991-07-02 2016-09-23 01:27:00  104897    5.118
# 88       Donna  Female 1991-11-27 2016-09-23 13:59:00   64088    6.155
# 116        NaN    Male 1991-06-22 2016-09-23 20:58:00   76189   18.988
# 148    Patrick     NaN 1991-07-14 2016-09-23 02:24:00  124488   14.837
# 166        NaN  Female 1991-07-09 2016-09-23 18:52:00   42341    7.014
# 172       Sara  Female 1991-09-23 2016-09-23 18:17:00   97058    9.402
# 220        NaN  Female 1991-06-17 2016-09-23 12:49:00   71945    5.560
# 245     Victor    Male 1991-04-11 2016-09-23 07:44:00   70817   17.138
# 277     Brenda     NaN 1991-05-29 2016-09-23 06:32:00   82439   19.062
# 313       Judy  Female 1991-07-01 2016-09-23 02:33:00  109510   13.457
# 328     Samuel    Male 1991-12-19 2016-09-23 02:54:00   76076    5.319
# 339    Michael    Male 1991-11-22 2016-09-23 12:57:00   98753   16.443
# 537    Cynthia  Female 1991-09-14 2016-09-23 13:08:00   51633   13.472
# 552    Barbara  Female 1991-09-02 2016-09-23 15:41:00  127297   11.905
# 603       Carl     NaN 1991-10-26 2016-09-23 08:11:00  100888   12.490
# 639     Amanda     NaN 1991-08-11 2016-09-23 14:15:00   46665   19.391
# 704     Thomas    Male 1991-09-07 2016-09-23 09:51:00   65251   11.211
# 725     Jeremy    Male 1991-05-19 2016-09-23 13:40:00  131513    1.876
# 766     Justin    Male 1991-07-25 2016-09-23 00:45:00  112975    9.699
# 771      Peter    Male 1991-05-22 2016-09-23 01:39:00  102577   12.026
# 783        NaN     NaN 1991-04-15 2016-09-23 03:39:00  132505   13.592
# 891    Timothy    Male 1991-08-25 2016-09-23 10:37:00   92587    8.475
# 895     Janice     NaN 1991-11-19 2016-09-23 18:02:00  139791   16.968
# 909     Donald    Male 1991-08-01 2016-09-23 02:25:00   61999    6.466
# 923      Irene     NaN 1991-02-28 2016-09-23 22:23:00  135369    4.380
# 989     Justin     NaN 1991-02-10 
# 855      Phillip     NaN 2003-10-20 2016-09-23 11:09:00   89700    2.277
# 860      Phillip    Male 1984-10-07 2016-09-23 11:05:00   36837   14.660
# 862       Ronald    Male 1983-05-25 2016-09-23 10:05:00   50426   18.536
# 871       Gerald    Male 2003-03-29 2016-09-23 10:37:00   96329    2.469
# 885         Juan    Male 1993-10-06 2016-09-23 08:52:00   85871    9.160
# 887        David    Male 2009-12-05 2016-09-23 08:48:00   92242   15.407
# 891      Timothy    Male 1991-08-25 2016-09-23 10:37:00   92587    8.475
# 894        Betty  Female 2002-11-19 2016-09-23 10:40:00   37005    7.645
# 897      Kenneth     NaN 1994-02-28 2016-09-23 10:10:00   95296   10.146
# 903      Heather  Female 1983-07-29 2016-09-23 10:48:00   47605   14.955
# 906      Frances  Female 2014-05-16 2016-09-23 08:31:00   35884   17.667
# 907    Elizabeth  Female 1998-07-27 2016-09-23 11:12:00  137144   10.081
# 912          Joe    Male 1998-12-08 2016-09-23 10:28:00  126120    1.020
# 919         Sean    Male 2009-03-21 2016-09-23 11:38:00  131423    8.957
# 922       Arthur    Male 2013-12-05 2016-09-23 08:44:00   86615    3.412
# 927       Philip    Male 2005-03-11 2016-09-23 10:56:00  103557   16.014
# 932       Bonnie  Female 2008-12-23 2016-09-23 09:26:00   90427    2.010
# 940       Andrew    Male 1990-09-28 2016-09-23 09:38:00  137386    8.611
# 941      William    Male 1997-06-26 2016-09-23 08:33:00  104840   15.653
# 943        Wayne    Male 2006-09-08 2016-09-23 11:09:00   67471    2.728
# 950        Paula  Female 1983-05-21 2016-09-23 11:42:00   58423   10.833
# 963          Ann  Female 1994-09-23 2016-09-23 11:15:00   89443   17.940
# 977        Sarah  Female 1995-12-04 2016-09-23 09:16:00  124566    5.949
# 982         Rose  Female 1982-04-06 2016-09-23 10:43:00   91411    8.639
# 988        Alice  Female 2004-10-05 2016-09-23 09:34:00   47638   11.209
# 992      Anthony    Male 2011-10-16 2016-09-23 08:35:00  112769   11.625
#
#     Senior Management                  Team
# 2               False               Finance
# 7                True               Finance
# 10               True                   NaN
# 18              False       Client Services
# 33              False  Business Development
# 40               True          Distribution
# 45               True                 Sales
# 54              False           Engineering
# 59              False           Engineering
# 72              False               Product
# 81              False                 Legal
# 85               True       Client Services
# 96              False               Finance
# 101              True             Marketing
# 109             False                   NaN
# 114              True  Business Development
# 121             False               Product
# 138              True           Engineering
# 143              True           Engineering
# 157              True               Product
# 161             False          Distribution
# 162              True                 Legal
# 170              True                 Sales
# 196             False       Client Services
# 204              True             Marketing
# 209             False           Engineering
# 212             False       Client Services
# 227              True       Client Services
# 230             False                 Legal
# 259              True       Human Resources
# ..                ...                   ...
# 828             False               Product
# 840              True          Distribution
# 850             False                   NaN
# 852              True  Business Development
# 855              True                   NaN
# 860             False             Marketing
# 862              True                 Sales
# 871              True           Engineering
# 885             False               Product
# 887             False                 Legal
# 891             False               Finance
# 894              True             Marketing
# 897             False               Finance
# 903              True       Human Resources
# 906             False                 Sales
# 907             False               Finance
# 912             False                   NaN
# 919             False          Distribution
# 922              True  Business Development
# 927              True  Business Development
# 932              True       Client Services
# 940              True          Distribution
# 941              True           Engineering
# 943             False           Engineering
# 950             False  Business Development
# 963              True                 Sales
# 977             False               Product
# 982              True       Human Resources
# 988             False       Human Resources
# 992              True               Finance
#
# [136 rows x 8 columns]

# %% [markdown]
# ## The `.duplicated()` Method

# %% [markdown]
# With the .duplicated() method we can call on a pndas series to get us a boolean series. And that's the duplicated method and it allows us to extract the rows from a data frame that are duplicates.

# %%
df = pd.read_csv("employees.csv", parse_dates = ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.sort_values("First Name", inplace = True)
df.head(3)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2020-04-02 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2020-04-02 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2020-04-02 14:53:00   52119   11.343
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services

# %%
# here we have duplicates on First Name
df["First Name"]
# Out:
# 101    Aaron
# 327    Aaron
# 440    Aaron
# 937    Aaron
# 137     Adam
#        ...
# 902      NaN
# 925      NaN
# 946      NaN
# 947      NaN
# 951      NaN
# Name: First Name, Length: 1000, dtype: object

# %% [markdown]
# The duplicated method by defaultit has this parameter called keep, and what keep is going to do is going to mark the very first occurrence of each value as a non-duplicate.
#
# So what that means is when we proceed downwards through the set, for the first time, it's going to take a look at Aaron here and say I haven't seen Aaron at all before. And then It's going to run into other Aaron values right below and they are going to be marked as duplicates.

# %%
df["First Name"].duplicated()
# Out:
# 101    False
# 327     True
# 440     True
# 937     True
# 137    False
#        ...
# 902     True
# 925     True
# 946     True
# 947     True
# 951     True
# Name: First Name, Length: 1000, dtype: bool

# %% [markdown]
# If we change the keep to last duplicated(keep = last) what it's going to do
# is view last Aaron as a unique value or not not a duplicate.

# %%
mask = df["First Name"].duplicated(keep = "last")
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2020-04-02 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2020-04-02 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2020-04-02 14:53:00   52119   11.343
# 137       Adam    Male 2011-05-21 2020-04-02 01:45:00   95327   15.120
# 141       Adam    Male 1990-12-24 2020-04-02 20:57:00  110194   14.727
# ..         ...     ...        ...                 ...     ...      ...
# 890        NaN    Male 2015-11-24 2020-04-02 03:11:00  145329    7.100
# 902        NaN    Male 2001-05-23 2020-04-02 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2020-04-02 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2020-04-02 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2020-04-02 15:07:00  107351    5.329
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 137              False     Distribution
# 141               True          Product
# ..                 ...              ...
# 890               True          Finance
# 902               True     Distribution
# 925               True            Sales
# 946               True     Distribution
# 947               True        Marketing
#
# [799 rows x 8 columns]

# %% [markdown]
# Now another common operation is what if you want to remove all of the rows that are unique. So I want to only have the rows where there are no duplicate first names just the unique names they have to occur only once.

# %%
mask = df["First Name"].duplicated(keep = False)
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2020-04-02 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2020-04-02 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2020-04-02 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2020-04-02 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2020-04-02 01:45:00   95327   15.120
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2020-04-02 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2020-04-02 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2020-04-02 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2020-04-02 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2020-04-02 05:19:00  143638    9.662
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution
# ..                 ...              ...
# 902               True     Distribution
# 925               True            Sales
# 946               True     Distribution
# 947               True        Marketing
# 951               True              NaN
#
# [991 rows x 8 columns]

# %% [markdown]
# If I use the symbol called tilda, you'll see that it's going to reverse all of the True's to falses and all of the falses to Trews.
#
# So now the trues that we have in this boolean series represent the unique values that only occur once in the first name column like before.

# %%
mask = ~df["First Name"].duplicated(keep = False)
df[mask]

# %% [markdown]
# ## The `.drop_duplicates()` Method

# %% [markdown]
# The drop drop_duplicates() method can be called on a dataframe instead of a series.
#
# So it allows us to do some of those similar filtering operations in a few less lines of code.

# %%
df = pd.read_csv("employees.csv", parse_dates = ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.sort_values("First Name", inplace = True)
df.head(3)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2020-04-02 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2020-04-02 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2020-04-02 14:53:00   52119   11.343
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services

# %%
len(df)
# Out:
# 1000

# %%
len(df.drop_duplicates())
# Out:
# 1000

# %%
df.drop_duplicates(subset = ["First Name"], keep = False)
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2016-09-05 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2016-09-05 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2016-09-05 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2016-09-05 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2016-09-05 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2016-09-05 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2016-09-05 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2016-09-05 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2016-09-05 10:30:00  132839   17.463
#
#     Senior Management                  Team
# 8                True           Engineering
# 688              True                 Legal
# 190             False               Finance
# 887             False                 Legal
# 5               False                 Legal
# 495             False                 Sales
# 33              False  Business Development
# 832             False                 Legal
# 291              True       Client Services

# %%
df.drop_duplicates(subset = ["First Name", "Team"], inplace = True)

# %%
df.head(2)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2016-09-05 10:20:00   61602   11.849
# 440      Aaron   Male 1990-07-22 2016-09-05 14:53:00   52119   11.343
#
#     Senior Management             Team
# 101              True        Marketing
# 440              True  Client Services

# %%
len(df)
# Out:
# 769

# %% [markdown]
# ## The `.unique()` and `.nunique()` Methods

# %% [markdown]
# Both .unique() and .nunique() Methods deal with finding the unique values within a series.

# %%
df = pd.read_csv("employees.csv", parse_dates = ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2016-10-18 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2016-10-18 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2016-10-18 11:17:00  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
df["Gender"].unique()

df["Team"].unique()
# Out:
# array(['Marketing', nan, 'Finance', 'Client Services', 'Legal', 'Product',
#        'Engineering', 'Business Development', 'Human Resources', 'Sales',
#        'Distribution'], dtype=object)

# %%
len(df["Team"].unique())
# Out:
# 11

# %%
df["Team"].nunique(dropna = False)
# Out:
# 11

# %% [markdown]
# <a href="https://colab.research.google.com/github/Zenologos/Data-Analysis/blob/master/US_Data_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import json
df = pd.read_csv('USvideos.csv')
df.head()
# Out:
#       video_id  ...                                        description
# 0  2kyS6SvSYSE  ...  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1  1ZAPwfrtAFY  ...  One year after the presidential election, John...
# 2  5qpjK5DgCt4  ...  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3  puqaWrEC7tY  ...  Today we find out if Link is a Nickelback amat...
# 4  d380meD0W0M  ...  I know it's been a while since we did this sho...
#
# [5 rows x 16 columns]

# %%
df.sort_values(['views', 'likes'], ascending=[False,True])
# Out:
#           video_id  ...                                        description
# 38547  VYOjWnS4cMY  ...  “This is America” by Childish Gambino http://s...
# 38345  VYOjWnS4cMY  ...  “This is America” by Childish Gambino http://s...
# 38146  VYOjWnS4cMY  ...  “This is America” by Childish Gambino http://s...
# 37935  VYOjWnS4cMY  ...  “This is America” by Childish Gambino http://s...
# 37730  VYOjWnS4cMY  ...  “This is America” by Childish Gambino http://s...
# ...            ...  ...                                                ...
# 546    -JVITToppE0  ...  Coach Taggart addresses the media ahead of the...
# 14531  dQMZLXaa1L8  ...  Artwork Forge II - an art installation created...
# 14782  y6KYFcta4SE  ...  Kentucky Gov. Matt Bevin confirmed there was a...
# 14563  y6KYFcta4SE  ...  Kentucky Gov. Matt Bevin confirmed there was a...
# 14335  y6KYFcta4SE  ...  Kentucky Gov. Matt Bevin confirmed there was a...
#
# [40949 rows x 16 columns]

# %%
df.sort_index
# Out:
# <bound method DataFrame.sort_index of           video_id  ...                                        description
# 0      2kyS6SvSYSE  ...  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      1ZAPwfrtAFY  ...  One year after the presidential election, John...
# 2      5qpjK5DgCt4  ...  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      puqaWrEC7tY  ...  Today we find out if Link is a Nickelback amat...
# 4      d380meD0W0M  ...  I know it's been a while since we did this sho...
# ...            ...  ...                                                ...
# 40944  BZt0qjTWNhw  ...     The Cat Who Caught the Laser - Aaron's Animals
# 40945  1h7KV2sjUWY  ...                                                NaN
# 40946  D6Oy4LfoqsU  ...  I had so much fun transforming Safiyas hair in...
# 40947  oV0zkMe1K8s  ...  How Black Panther Should Have EndedWatch More ...
# 40948  ooyjaVdt-jA  ...  Call of Duty: Black Ops 4 Multiplayer raises t...
#
# [40949 rows x 16 columns]>

# %%
df.sort_index(ascending=True)
# Out:
#           video_id  ...                                        description
# 0      2kyS6SvSYSE  ...  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      1ZAPwfrtAFY  ...  One year after the presidential election, John...
# 2      5qpjK5DgCt4  ...  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      puqaWrEC7tY  ...  Today we find out if Link is a Nickelback amat...
# 4      d380meD0W0M  ...  I know it's been a while since we did this sho...
# ...            ...  ...                                                ...
# 40944  BZt0qjTWNhw  ...     The Cat Who Caught the Laser - Aaron's Animals
# 40945  1h7KV2sjUWY  ...                                                NaN
# 40946  D6Oy4LfoqsU  ...  I had so much fun transforming Safiyas hair in...
# 40947  oV0zkMe1K8s  ...  How Black Panther Should Have EndedWatch More ...
# 40948  ooyjaVdt-jA  ...  Call of Duty: Black Ops 4 Multiplayer raises t...
#
# [40949 rows x 16 columns]

# %%
df['Rank'] = df['views'].rank(ascending=False).astype(int)
df['Rank']
# Out:
# 0        19485
# 1         7952
# 2         6083
# 3        27528
# 4         9068
#          ...
# 40944    10903
# 40945    15600
# 40946    15578
# 40947     3295
# 40948     1792
# Name: Rank, Length: 40949, dtype: int64

# %%
df.head(5)
# Out:
#       video_id  ...   Rank
# 0  2kyS6SvSYSE  ...  19485
# 1  1ZAPwfrtAFY  ...   7952
# 2  5qpjK5DgCt4  ...   6083
# 3  puqaWrEC7tY  ...  27528
# 4  d380meD0W0M  ...   9068
#
# [5 rows x 17 columns]

# %%
df[df['category_id']==22]
# Out:
#           video_id  ...   Rank
# 0      2kyS6SvSYSE  ...  19485
# 35     0mlNzVSJrT0  ...  35666
# 44     STI2fI7sKMo  ...  28141
# 54     KODzih-pYlU  ...  32231
# 66     8mhTWqWlQzU  ...   7031
# ...            ...  ...    ...
# 40885  wI6a1t-M_48  ...   6972
# 40897  ZKZwrlNHMkk  ...  10804
# 40902  jxWJLs7_doc  ...   5561
# 40943  1PhPYr_9zRY  ...   2279
# 40945  1h7KV2sjUWY  ...  15600
#
# [3210 rows x 17 columns]

# %%
mask1= df['category_id']==22
mask2= df['views']>500000
df[mask1&mask2]
# Out:
#           video_id  ...   Rank
# 0      2kyS6SvSYSE  ...  19485
# 66     8mhTWqWlQzU  ...   7031
# 100    fCTKDn3Q8xQ  ...  15242
# 154    P4YJwy_T9pM  ...  20323
# 217    2kyS6SvSYSE  ...   8705
# ...            ...  ...    ...
# 40885  wI6a1t-M_48  ...   6972
# 40897  ZKZwrlNHMkk  ...  10804
# 40902  jxWJLs7_doc  ...   5561
# 40943  1PhPYr_9zRY  ...   2279
# 40945  1h7KV2sjUWY  ...  15600
#
# [1704 rows x 17 columns]

# %%
mask3= df['likes']>5000000
mm=df[mask1&(mask2|mask3)]
mm[['category_id','likes','views']]
# Out:
#        category_id   likes    views
# 0               22   57527   748374
# 66              22  115426  2744430
# 100             22   43875  1098897
# 154             22   31892   691229
# 217             22   88099  2188590
# ...            ...     ...      ...
# 40885           22   81319  2771306
# 40897           22   26568  1705452
# 40902           22   91836  3464680
# 40943           22  645888  8259128
# 40945           22   60008  1064798
#
# [1704 rows x 3 columns]

# %%
df['category_id'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 40944    False
# 40945    False
# 40946    False
# 40947    False
# 40948    False
# Name: category_id, Length: 40949, dtype: bool

# %%
df['category_id'].notnull()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 40944    True
# 40945    True
# 40946    True
# 40947    True
# 40948    True
# Name: category_id, Length: 40949, dtype: bool

# %%
df.dropna()
# Out:
#           video_id  ...   Rank
# 0      2kyS6SvSYSE  ...  19485
# 1      1ZAPwfrtAFY  ...   7952
# 2      5qpjK5DgCt4  ...   6083
# 3      puqaWrEC7tY  ...  27528
# 4      d380meD0W0M  ...   9068
# ...            ...  ...    ...
# 40943  1PhPYr_9zRY  ...   2279
# 40944  BZt0qjTWNhw  ...  10903
# 40946  D6Oy4LfoqsU  ...  15578
# 40947  oV0zkMe1K8s  ...   3295
# 40948  ooyjaVdt-jA  ...   1792
#
# [40379 rows x 17 columns]

# %%
df[df['views'].between(50000000,51000000)]
# Out:
#           video_id  ... Rank
# 24858  tCXGJQYZ9JA  ...  173
# 26066  QwievZ1Tx-8  ...  176
# 29454  i0p1bmr0EmE  ...  177
# 35525  DkeiKbqa02g  ...  174
# 39337  ulNswX3If6U  ...  175
#
# [5 rows x 17 columns]

# %%
df['video_id'].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 40944     True
# 40945     True
# 40946     True
# 40947     True
# 40948     True
# Name: video_id, Length: 40949, dtype: bool

# %%
df[df['video_id'].duplicated()==False]
# Out:
#           video_id  ...   Rank
# 0      2kyS6SvSYSE  ...  19485
# 1      1ZAPwfrtAFY  ...   7952
# 2      5qpjK5DgCt4  ...   6083
# 3      puqaWrEC7tY  ...  27528
# 4      d380meD0W0M  ...   9068
# ...            ...  ...    ...
# 40760  dS5Thrl-4Kc  ...  21719
# 40761  JGm9Y_hFqNk  ...  18616
# 40762  6h8QgZF5Qu4  ...  17955
# 40764  mpnshdmtE2Y  ...  22951
# 40766  yz7Xq3T0YPs  ...  28922
#
# [6351 rows x 17 columns]

# %%
df['video_id'].duplicated(keep = "last")
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 40944    False
# 40945    False
# 40946    False
# 40947    False
# 40948    False
# Name: video_id, Length: 40949, dtype: bool

# %%
len(df['channel_title'].drop_duplicates())
# Out:
# 2207

# %%
df['channel_title'].drop_duplicates(keep='first')
# Out:
# 0                    CaseyNeistat
# 1                 LastWeekTonight
# 2                    Rudy Mancuso
# 3           Good Mythical Morning
# 4                        nigahiga
#                    ...
# 40366                        HALO
# 40475              Ben Kronengold
# 40488             All Def Digital
# 40540    How It Should Have Ended
# 40554       Ubisoft North America
# Name: channel_title, Length: 2207, dtype: object

# %%
len(df['channel_title'])
# Out:
# 40949

# %%
len(df['video_id'].unique())
# Out:
# 6351

# %%
df['video_id'].nunique()
# Out:
# 6351

# %%
df['video_id'].unique()
# Out:
# array(['2kyS6SvSYSE', '1ZAPwfrtAFY', '5qpjK5DgCt4', ..., '6h8QgZF5Qu4',
#        'mpnshdmtE2Y', 'yz7Xq3T0YPs'], dtype=object)

# %%
df.set_index('likes',inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-a614ee9c0fe2> in <module>()
# ----> 1 df.set_index('likes',inplace=True)
#       2 df.head()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['likes'] are in the columns"

# %%
df.head()
# Out:
#            video_id  ...                                        description
# likes                ...
# 57527   2kyS6SvSYSE  ...  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 97185   1ZAPwfrtAFY  ...  One year after the presidential election, John...
# 146033  5qpjK5DgCt4  ...  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 10172   puqaWrEC7tY  ...  Today we find out if Link is a Nickelback amat...
# 132235  d380meD0W0M  ...  I know it's been a while since we did this sho...
#
# [5 rows x 15 columns]

# %%
df.reset_index(drop= False, inplace=True)

# %%
df.head()
# Out:
#     likes  ...                                        description
# 0   57527  ...  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1   97185  ...  One year after the presidential election, John...
# 2  146033  ...  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3   10172  ...  Today we find out if Link is a Nickelback amat...
# 4  132235  ...  I know it's been a while since we did this sho...
#
# [5 rows x 16 columns]

# %%
df.set_index('category_id',inplace=True)
df.head()
# Out:
#               likes  ...                                        description
# category_id          ...
# 22            57527  ...  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 24            97185  ...  One year after the presidential election, John...
# 23           146033  ...  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 24            10172  ...  Today we find out if Link is a Nickelback amat...
# 24           132235  ...  I know it's been a while since we did this sho...
#
# [5 rows x 15 columns]

# %%
df.loc[22]
# Out:
#               likes  ...                                        description
# category_id          ...
# 22            57527  ...  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 22             2486  ...  Kittens come out of the eggs in a Thai commerc...
# 22             4451  ...  Subscribe for weekly videos ▶ http://bit.ly/sj...
# 22             7250  ...  Molly is an god damn amazing human and she cha...
# 22           115426  ...  I found this online dollar store called ShopMi...
# ...             ...  ...                                                ...
# 22            81319  ...  In front of Hillary...?Ben Kronengold: @benkgo...
# 22            26568  ...  Click Here To Join The Family! ► http://bit.ly...
# 22            91836  ...  I wanted you guys to hear this awesome new son...
# 22           645888  ...  BTS with the PPS, the puppies. These adorable ...
# 22            60008  ...                                                NaN
#
# [3210 rows x 15 columns]

# %%
df['trending_date']=pd.to_datetime(df['trending_date'], format='%y.%d.%m')

# %%
df.head(5)
# Out:
#               likes  ...                                        description
# category_id          ...
# 22            57527  ...  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 24            97185  ...  One year after the presidential election, John...
# 23           146033  ...  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 24            10172  ...  Today we find out if Link is a Nickelback amat...
# 24           132235  ...  I know it's been a while since we did this sho...
#
# [5 rows x 15 columns]

# %%
df['publish_time']=pd.to_datetime(df['publish_time'], format='%Y-%m-%dT%H:%M:%S.%fZ')
df['publish_time'].head()
# Out:
# category_id
# 22   2017-11-13 17:13:01
# 24   2017-11-13 07:30:00
# 23   2017-11-12 19:05:24
# 24   2017-11-13 11:00:04
# 24   2017-11-12 18:01:41
# Name: publish_time, dtype: datetime64[ns]

# %%
df.insert(4, 'publish_date', df['publish_time'].dt.date)

# %%
df.head(5)
# Out:
#               likes  ...                                        description
# category_id          ...
# 22            57527  ...  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 24            97185  ...  One year after the presidential election, John...
# 23           146033  ...  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 24            10172  ...  Today we find out if Link is a Nickelback amat...
# 24           132235  ...  I know it's been a while since we did this sho...
#
# [5 rows x 16 columns]

# %%
df['publish_time'] = df['publish_time'].dt.time

# %%
df.head(5)
# Out:
#               likes  ...                                        description
# category_id          ...
# 22            57527  ...  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 24            97185  ...  One year after the presidential election, John...
# 23           146033  ...  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 24            10172  ...  Today we find out if Link is a Nickelback amat...
# 24           132235  ...  I know it's been a while since we did this sho...
#
# [5 rows x 16 columns]

# %%
df.loc[24]
# Out:
# video_id                                                        lZ68j2J_GOM
# trending_date                                                      17.14.11
# title                                          Using Other People's Showers
# channel_title                                                   Gus Johnson
# category_id                                                              23
# publish_time                                       2017-11-13T14:44:24.000Z
# tags                      using other peoples showers|"gus"|"gus shower"...
# views                                                                 33980
# likes                                                                  4884
# dislikes                                                                 52
# comment_count                                                           234
# thumbnail_link               https://i.ytimg.com/vi/lZ68j2J_GOM/default.jpg
# ...

# %%
df.loc[33]
# Out:
# video_id                                                        hz7ukDjuq4w
# trending_date                                                      17.14.11
# title                                       What's Inside a Detectives Car?
# channel_title                                                    officer401
# category_id                                                              24
# publish_time                                       2017-11-12T23:41:37.000Z
# tags                      detective|"officer"|"401"|"officer401"|"police...
# views                                                                 67661
# likes                                                                  3781
# dislikes                                                                 84
# comment_count                                                           626
# thumbnail_link               https://i.ytimg.com/vi/hz7ukDjuq4w/default.jpg
# ...

# %%
df.set_index('category_id',inplace=True)

# %%
df.head()
# Out:
#                 video_id  ...                                        description
# category_id               ...
# 22           2kyS6SvSYSE  ...  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 24           1ZAPwfrtAFY  ...  One year after the presidential election, John...
# 23           5qpjK5DgCt4  ...  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 24           puqaWrEC7tY  ...  Today we find out if Link is a Nickelback amat...
# 24           d380meD0W0M  ...  I know it's been a while since we did this sho...
#
# [5 rows x 15 columns]

# %%
df.loc[:24]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-d80b2940c5b3> in <module>()
# ----> 1 df.loc[:24]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1910         if isinstance(key, slice):
#    1911             self._validate_key(key, axis)
# -> 1912             return self._get_slice_axis(key, axis=axis)
#    1913         elif com.is_bool_indexer(key):
#    1914             return self._getbool_axis(key, axis=axis)
#
# ...

# %%
df.head()
# Out:
#                 video_id  ...                                        description
# category_id               ...
# 22           2kyS6SvSYSE  ...  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 24           1ZAPwfrtAFY  ...  One year after the presidential election, John...
# 23           5qpjK5DgCt4  ...  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 24           puqaWrEC7tY  ...  Today we find out if Link is a Nickelback amat...
# 24           d380meD0W0M  ...  I know it's been a while since we did this sho...
#
# [5 rows x 15 columns]

# %%
df.loc[24:]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-75403c6cc570> in <module>()
# ----> 1 df.loc[24:]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1910         if isinstance(key, slice):
#    1911             self._validate_key(key, axis)
# -> 1912             return self._get_slice_axis(key, axis=axis)
#    1913         elif com.is_bool_indexer(key):
#    1914             return self._getbool_axis(key, axis=axis)
#
# ...

# %%
df.loc[24]
# Out:
#                 video_id  ...                                        description
# category_id               ...
# 24           1ZAPwfrtAFY  ...  One year after the presidential election, John...
# 24           puqaWrEC7tY  ...  Today we find out if Link is a Nickelback amat...
# 24           d380meD0W0M  ...  I know it's been a while since we did this sho...
# 24           39idVpFF7NQ  ...  Embattled Alabama Senate candidate Roy Moore (...
# 24           VifQlJit6A0  ...  Shiva arrives just in time as King Ezekiel att...
# ...                  ...  ...                                                ...
# 24           wI89nVn6LHk  ...  Maddie Poppe the crowd the American Idol 2018 ...
# 24           tiF9SzzzX_o  ...  Brynn Cartelli sings Adele's Skyfall during th...
# 24           Qcj15vHJTtk  ...  Footage from Prince Harry's (Mikey Day) weddin...
# 24           _QWZvU7VCn8  ...  Check out all that Emilia Clarke merch... Subs...
# ...

# %%
df.iloc[:24]
# Out:
#                 video_id  ...                                        description
# category_id               ...
# 22           2kyS6SvSYSE  ...  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 24           1ZAPwfrtAFY  ...  One year after the presidential election, John...
# 23           5qpjK5DgCt4  ...  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 24           puqaWrEC7tY  ...  Today we find out if Link is a Nickelback amat...
# 24           d380meD0W0M  ...  I know it's been a while since we did this sho...
# 28           gHZ1Qz0KiKM  ...  Using the iPhone for the past two weeks -- her...
# 24           39idVpFF7NQ  ...  Embattled Alabama Senate candidate Roy Moore (...
# 28           nc99ccSXST0  ...  Ice Cream Pint Combination Lock - http://amzn....
# 1            jr9QtXwC9vc  ...  Inspired by the imagination of P.T. Barnum, Th...
# 25           TUmyygCMMGA  ...  For now, at least, we have better things to wo...
# ...

# %%
df.iloc[24:]
# Out:
#                 video_id  ...                                        description
# category_id               ...
# 23           lZ68j2J_GOM  ...  Why is it so hard to figure out other people's...
# 24           dRpNZV18N_g  ...  Visit http://www.Bongiovibrand.com\nand get 20...
# 28           fcVjitaM3LY  ...  James Grime is back and talking prime numbers....
# 26           qeWvgZLz9yU  ...  YouTubes new channel!: https://www.youtube.com...
# 25           iIxy3JN3-jc  ...  LeBron James gave another all-time press confe...
# ...                  ...  ...                                                ...
# 15           BZt0qjTWNhw  ...     The Cat Who Caught the Laser - Aaron's Animals
# 22           1h7KV2sjUWY  ...                                                NaN
# 24           D6Oy4LfoqsU  ...  I had so much fun transforming Safiyas hair in...
# 1            oV0zkMe1K8s  ...  How Black Panther Should Have EndedWatch More ...
# ...

# %%
df.iloc[22:24]
# Out:
#                 video_id  ...                                        description
# category_id               ...
# 27           _-aDHxoblr4  ...  I'm visiting the University of Iowa's National...
# 26           JBZTZZAcFTw  ...  On this episode of Sweet Digs, we tour Social ...
#
# [2 rows x 15 columns]

# %%
df.iloc[22,24]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-2baf0cd41b7c> in <module>()
# ----> 1 df.iloc[22,24]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    2065     def _getitem_tuple(self, tup: Tuple):
#    2066
# -> 2067         self._has_valid_tuple(tup)
#    2068         try:
#    2069             return self._getitem_lowerdim(tup)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
# ...

# %%
df.reset_index
# Out:
# <bound method DataFrame.reset_index of                 video_id  ...                                        description
# category_id               ...
# 22           2kyS6SvSYSE  ...  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 24           1ZAPwfrtAFY  ...  One year after the presidential election, John...
# 23           5qpjK5DgCt4  ...  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 24           puqaWrEC7tY  ...  Today we find out if Link is a Nickelback amat...
# 24           d380meD0W0M  ...  I know it's been a while since we did this sho...
# ...                  ...  ...                                                ...
# 15           BZt0qjTWNhw  ...     The Cat Who Caught the Laser - Aaron's Animals
# 22           1h7KV2sjUWY  ...                                                NaN
# 24           D6Oy4LfoqsU  ...  I had so much fun transforming Safiyas hair in...
# 1            oV0zkMe1K8s  ...  How Black Panther Should Have EndedWatch More ...
# ...

# %%
df.reset_index(drop=False, inplace=True)

# %%
df.loc[[22,24]]
# Out:
#     category_id  ...                                        description
# 22           27  ...  I'm visiting the University of Iowa's National...
# 24           23  ...  Why is it so hard to figure out other people's...
#
# [2 rows x 16 columns]

# %%
df.iloc[[22,24]]
# Out:
#     category_id  ...                                        description
# 22           27  ...  I'm visiting the University of Iowa's National...
# 24           23  ...  Why is it so hard to figure out other people's...
#
# [2 rows x 16 columns]

# %%
df.iloc[[24,44]]
# Out:
#     category_id  ...                                        description
# 24           23  ...  Why is it so hard to figure out other people's...
# 44           22  ...  Subscribe for weekly videos ▶ http://bit.ly/sj...
#
# [2 rows x 16 columns]

# %%
df.nlargest(3, columns = 'likes')
# Out:
#        category_id  ...                                        description
# 38273           10  ...  BTS (방탄소년단) 'FAKE LOVE' Official MVDirector : ...
# 38072           10  ...  BTS (방탄소년단) 'FAKE LOVE' Official MVDirector : ...
# 37861           10  ...  BTS (방탄소년단) 'FAKE LOVE' Official MVDirector : ...
#
# [3 rows x 16 columns]

# %%
df.nsmallest(5, columns='likes')
# Out:
#       category_id  ...                                        description
# 192            22  ...  Clips 2.0 lets you use augmented reality and s...
# 1435            1  ...  The Hudson Union www.hudsonunionsociety.com is...
# 1490           17  ...  I'm BACK! \n\n• Will you be apart of the take ...
# 1667            1  ...  The Hudson Union www.hudsonunionsociety.com is...
# 1741           17  ...  I'm BACK! \n\n• Will you be apart of the take ...
#
# [5 rows x 16 columns]

# %%
df.query('likes>5000000')
# Out:
#        category_id  ...                                        description
# 36397           10  ...  BTS (방탄소년단) 'FAKE LOVE' Official MVDirector : ...
# 36611           10  ...  BTS (방탄소년단) 'FAKE LOVE' Official MVDirector : ...
# 36816           10  ...  BTS (방탄소년단) 'FAKE LOVE' Official MVDirector : ...
# 37031           10  ...  BTS (방탄소년단) 'FAKE LOVE' Official MVDirector : ...
# 37247           10  ...  BTS (방탄소년단) 'FAKE LOVE' Official MVDirector : ...
# 37453           10  ...  BTS (방탄소년단) 'FAKE LOVE' Official MVDirector : ...
# 37655           10  ...  BTS (방탄소년단) 'FAKE LOVE' Official MVDirector : ...
# 37861           10  ...  BTS (방탄소년단) 'FAKE LOVE' Official MVDirector : ...
# 38072           10  ...  BTS (방탄소년단) 'FAKE LOVE' Official MVDirector : ...
# 38273           10  ...  BTS (방탄소년단) 'FAKE LOVE' Official MVDirector : ...
# 38547           10  ...  “This is America” by Childish Gambino http://s...
#
# [11 rows x 16 columns]

# %%
def trending(row):
    
    likes = row[9]
    cat_id = row[5]
    
    if likes >10000 :
    #and cat_id =='22':
        return "The best"
    elif likes > 500 :
    #and cat_id == '24':
        return "Enjoyable"
    else:
        return 'Annoying'

# %%
df = pd.read_csv('USvideos.csv')

# %%
df.head()
# Out:
#       video_id  ...                                        description
# 0  2kyS6SvSYSE  ...  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1  1ZAPwfrtAFY  ...  One year after the presidential election, John...
# 2  5qpjK5DgCt4  ...  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3  puqaWrEC7tY  ...  Today we find out if Link is a Nickelback amat...
# 4  d380meD0W0M  ...  I know it's been a while since we did this sho...
#
# [5 rows x 16 columns]

# %%
df.apply(trending, axis='columns')
# Out:
# 0        Enjoyable
# 1        Enjoyable
# 2        Enjoyable
# 3        Enjoyable
# 4        Enjoyable
#            ...
# 40944    Enjoyable
# 40945     Annoying
# 40946    Enjoyable
# 40947    Enjoyable
# 40948     The best
# Length: 40949, dtype: object

# %%
trending[100]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-894f8a5e1540> in <module>()
# ----> 1 trending[100]
#
# TypeError: 'function' object is not subscriptable

# %%
df2=df[['views','likes']]
df2
df2c = df2.copy()

# %%
df2
# Out:
#           views   likes
# 0        748374   57527
# 1       2418783   97185
# 2       3191434  146033
# 3        343168   10172
# 4       2095731  132235
# ...         ...     ...
# 40944   1685609   38160
# 40945   1064798   60008
# 40946   1066451   48068
# 40947   5660813  192957
# 40948  10306119  357079
#
# [40949 rows x 2 columns]

# %%
df2c
# Out:
#           views   likes
# 0        748374   57527
# 1       2418783   97185
# 2       3191434  146033
# 3        343168   10172
# 4       2095731  132235
# ...         ...     ...
# 40944   1685609   38160
# 40945   1064798   60008
# 40946   1066451   48068
# 40947   5660813  192957
# 40948  10306119  357079
#
# [40949 rows x 2 columns]
